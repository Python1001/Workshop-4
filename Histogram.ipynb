# %% [markdown]
# # Demonstration of Drawing Graphs

# %%
import matplotlib.pyplot as plt
import numpy as np

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
hist, bins = np.histogram(x, bins=50)
width = 0.5 * (bins[1] - bins[0])
center = (bins[:-1] + bins[1:]) / 2
plt.bar(center, hist, align='center', width=width)
plt.show()

# %%
bins[:-1]
# Out:
# array([  46.95191423,   49.09054487,   51.22917551,   53.36780615,
#          55.50643679,   57.64506743,   59.78369807,   61.92232872,
#          64.06095936,   66.19959   ,   68.33822064,   70.47685128,
#          72.61548192,   74.75411257,   76.89274321,   79.03137385,
#          81.17000449,   83.30863513,   85.44726577,   87.58589642,
#          89.72452706,   91.8631577 ,   94.00178834,   96.14041898,
#          98.27904962,  100.41768026,  102.55631091,  104.69494155,
#         106.83357219,  108.97220283,  111.11083347,  113.24946411,
#         115.38809476,  117.5267254 ,  119.66535604,  121.80398668,
#         123.94261732,  126.08124796,  128.2198786 ,  130.35850925,
#         132.49713989,  134.63577053,  136.77440117,  138.91303181,
#         141.05166245,  143.1902931 ,  145.32892374,  147.46755438,
#         149.60618502,  151.74481566])

# %%
bins[1:]
# Out:
# array([  49.09054487,   51.22917551,   53.36780615,   55.50643679,
#          57.64506743,   59.78369807,   61.92232872,   64.06095936,
#          66.19959   ,   68.33822064,   70.47685128,   72.61548192,
#          74.75411257,   76.89274321,   79.03137385,   81.17000449,
#          83.30863513,   85.44726577,   87.58589642,   89.72452706,
#          91.8631577 ,   94.00178834,   96.14041898,   98.27904962,
#         100.41768026,  102.55631091,  104.69494155,  106.83357219,
#         108.97220283,  111.11083347,  113.24946411,  115.38809476,
#         117.5267254 ,  119.66535604,  121.80398668,  123.94261732,
#         126.08124796,  128.2198786 ,  130.35850925,  132.49713989,
#         134.63577053,  136.77440117,  138.91303181,  141.05166245,
#         143.1902931 ,  145.32892374,  147.46755438,  149.60618502,
#         151.74481566,  153.8834463 ])

# %%
bins[1], bins[0]
# Out:
# (49.090544867256313, 46.951914225713651)

# %%
import numpy as np
import matplotlib.mlab as mlab
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma*np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='green', alpha=0.75)

# add a 'best fit' line
y = mlab.normpdf( bins, mu, sigma)
l = plt.plot(bins, y, 'r--', linewidth=1)

plt.xlabel('IQ results')
plt.ylabel('Probability')
plt.title(r'$\mathrm{Histogram\ of\ IQ:}\ \mu=100,\ \sigma=15$')
plt.axis([30, 160, 0, 0.035])
plt.grid(True)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
x = np.random.normal(size = 1000)
plt.hist(x, normed=True, bins=30) # bin = slice size
plt.ylabel('Probability');

# %%
x = np.arange(3)
plt.bar(x, height= [4,2,3])
plt.xticks(x, ['a','b','c']);
