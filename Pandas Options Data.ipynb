# %%
import pandas_datareader as pdr
pdr.get_data_yahoo('AAPL')
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2010-01-04  213.429998  214.499996  212.380001  214.009998  123432400
# 2010-01-05  214.599998  215.589994  213.249994  214.379993  150476200
# 2010-01-06  214.379993  215.230000  210.750004  210.969995  138040000
# 2010-01-07  211.750000  212.000006  209.050005  210.580000  119282800
# 2010-01-08  210.299994  212.000006  209.060005  211.980005  111902700
# 2010-01-11  212.799997  213.000002  208.450005  210.110003  115557400
# 2010-01-12  209.189995  209.769995  206.419998  207.720001  148614900
# 2010-01-13  207.870005  210.929995  204.099998  210.650002  151473000
# 2010-01-14  210.110003  210.459997  209.020004  209.430000  108223500
# 2010-01-15  210.929995  211.599997  205.869999  205.930000  148516900
# 2010-01-19  208.330002  215.189999  207.240004  215.039995  182501900
# 2010-01-20  214.910006  215.549994  209.500002  211.730000  153038200
# ...

# %%
#Historical stock prices from Yahoo! Finance
import pandas_datareader as web
import datetime

# %%
start = datetime.datetime(2010, 1, 1)
end = datetime.datetime(2013,1,2)

# %%
f = web.DataReader("AAPL", 'yahoo', start, end)

# %%
f.head(10)
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2010-01-04  213.429998  214.499996  212.380001  214.009998  123432400
# 2010-01-05  214.599998  215.589994  213.249994  214.379993  150476200
# 2010-01-06  214.379993  215.230000  210.750004  210.969995  138040000
# 2010-01-07  211.750000  212.000006  209.050005  210.580000  119282800
# 2010-01-08  210.299994  212.000006  209.060005  211.980005  111902700
# 2010-01-11  212.799997  213.000002  208.450005  210.110003  115557400
# 2010-01-12  209.189995  209.769995  206.419998  207.720001  148614900
# 2010-01-13  207.870005  210.929995  204.099998  210.650002  151473000
# 2010-01-14  210.110003  210.459997  209.020004  209.430000  108223500
# 2010-01-15  210.929995  211.599997  205.869999  205.930000  148516900
#
#             Adj Close
# Date
# 2010-01-04  27.727039
# 2010-01-05  27.774976
# 2010-01-06  27.333178
# 2010-01-07  27.282650
# 2010-01-08  27.464034
# 2010-01-11  27.221758
# ...

# %%
f.ix['2010-01-15']
# Out:
# Open         2.109300e+02
# High         2.116000e+02
# Low          2.058700e+02
# Close        2.059300e+02
# Volume       1.485169e+08
# Adj Close    2.668020e+01
# Name: 2010-01-15 00:00:00, dtype: float64

# %%
#Yahoo! Finance Options
from pandas_datareader.data import Options
aapl = Options('AAPL', 'yahoo')
data = aapl.get_all_data()
data.iloc[0:80, 0:80] #increase the number will get more series of option strikes
# Out:
#                                               Last     Bid     Ask       Chg  \
# Strike Expiry     Type Symbol
# 2.5    2017-05-19 put  AAPL170519P00002500    0.02    0.00    0.02  0.000000
#        2017-06-16 put  AAPL170616P00002500    0.01    0.00    0.01 -0.010000
# 5.0    2017-05-19 put  AAPL170519P00005000    0.02    0.00    0.02  0.000000
# 20.0   2017-05-19 call AAPL170519C00020000  124.00  122.95  123.85  0.000000
# 25.0   2017-07-21 call AAPL170721C00025000   86.80   83.30   84.80  0.000000
#                   put  AAPL170721P00025000    0.02    0.00    0.02  0.000000
# 30.0   2017-07-21 put  AAPL170721P00030000    0.03    0.00    0.04  0.000000
# 35.0   2017-05-19 call AAPL170519C00035000   96.80   96.85   97.60  0.000000
#        2017-07-21 put  AAPL170721P00035000    0.04    0.01    0.05  0.000000
# 40.0   2017-07-21 call AAPL170721C00040000   71.74    0.00    0.00  0.000000
#                   put  AAPL170721P00040000    0.04    0.03    0.10  0.000000
# ...

# %%
data.loc[(100, slice(None), 'put'),:].iloc[0:5, 0:5]
# Out:
#                                             Last   Bid   Ask   Chg      PctChg
# Strike Expiry     Type Symbol
# 100.0  2017-05-05 put  AAPL170505P00100000  0.02  0.00  0.04  0.01  100.000000
#        2017-05-19 put  AAPL170519P00100000  0.01  0.00  0.02 -0.01  -50.000000
#        2017-05-26 put  AAPL170526P00100000  0.04  0.01  0.05  0.00    0.000000
#        2017-06-16 put  AAPL170616P00100000  0.03  0.02  0.04  0.00    0.000000
#        2017-07-21 put  AAPL170721P00100000  0.04  0.03  0.05 -0.01  -20.000004

# %%
data.loc[(100, slice(None), 'put'),'Vol'].head()
# Out:
# Strike  Expiry      Type  Symbol
# 100.0   2017-05-05  put   AAPL170505P00100000    100.0
#         2017-05-19  put   AAPL170519P00100000     25.0
#         2017-05-26  put   AAPL170526P00100000      2.0
#         2017-06-16  put   AAPL170616P00100000      1.0
#         2017-07-21  put   AAPL170721P00100000      3.0
# Name: Vol, dtype: float64

# %%
data = aapl.get_near_stock_price(expiry=aapl.expiry_dates[0:3])

# %%
data.iloc[0:5:, 0:5]
# Out:
#                                             Last   Bid   Ask   Chg     PctChg
# Strike Expiry     Type Symbol
# 144.0  2017-05-12 call AAPL170512C00144000  2.53  2.45  2.50 -0.19  -6.985296
#        2017-05-19 call AAPL170519C00144000  2.65  2.62  2.68 -0.38 -13.240422
# 145.0  2017-05-05 call AAPL170505C00145000  1.80  1.77  1.82 -0.24 -11.764707
#        2017-05-12 call AAPL170512C00145000  2.05  1.97  2.04 -0.13  -5.963308
#        2017-05-19 call AAPL170519C00145000  2.18  2.16  2.20 -0.19  -8.016870

# %%
# Economic Indicators
# GDP per capital in constant dollars
from pandas_datareader import wb
wb.search('gdp.*capita.*const').iloc[:,:2]
# Out:
#                       id                                               name
# 685   6.0.GDPpc_constant  GDP per capita, PPP (constant 2011 internation...
# 7588      NY.GDP.PCAP.KD                 GDP per capita (constant 2010 US$)
# 7590      NY.GDP.PCAP.KN                      GDP per capita (constant LCU)
# 7592   NY.GDP.PCAP.PP.KD  GDP per capita, PPP (constant 2011 internation...

# %%
# Acquire the data from the World Bank’s servers
dat = wb.download(indicator='NY.GDP.PCAP.KD', country=['CA', 'MX', 'US'], start=2010, end=2015)
print(dat)
# Out:
#                     NY.GDP.PCAP.KD
# country       year
# Canada        2015    50108.065004
#               2014    50065.234068
#               2013    49353.313639
#               2012    48722.485586
#               2011    48455.214016
#               2010    47445.761935
# Mexico        2015     9510.596254
#               2014     9402.569128
#               2013     9318.395096
#               2012     9319.064370
#               2011     9086.031941
#               2010     8861.493720
# United States 2015    51638.065207
#               2014    50727.751210
#               2013    49941.489109
#               2012    49481.158654
#               2011    48774.783088
#               2010    48374.086793
