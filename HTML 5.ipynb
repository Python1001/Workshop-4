# %% [markdown]
# # Get Webpage information such as table

# %%
import pandas as pd
import html5lib

# %%
table = pd.read_html('https://en.wikipedia.org/wiki/List_of_states_and_territories_of_the_United_States')

# %%
table[0]
# Out:
#                               0               1               2  \
# 0   State & postal abbreviation          Cities    Statehood[A]
# 1                       Capital  Largest[C][17]  (2016 est)[18]
# 2                       Alabama              AL      Montgomery
# 3                        Alaska              AK          Juneau
# 4                       Arizona              AZ         Phoenix
# 5                      Arkansas              AR     Little Rock
# 6                    California              CA      Sacramento
# 7                      Colorado              CO          Denver
# 8                   Connecticut              CT        Hartford
# 9                      Delaware              DE           Dover
# 10                      Florida              FL     Tallahassee
# 11                      Georgia              GA         Atlanta
# 12                       Hawaii              HI        Honolulu
# 13                        Idaho              ID           Boise
# ...
